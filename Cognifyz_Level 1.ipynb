# %% [markdown]
# __Level - 1 Task - 1
#   Task: Data Exploration and Preprocessing__

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
re = pd.read_csv("cognify.csv")
re.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
re.shape
# Out:
# (9551, 21)

# %%
# Exploring the dataset

print("Number of rows and columns:")
print(re.shape)
# Out:
# Number of rows and columns:
# (9551, 21)

# %%
# Statistical Summary

print("\nStatistical Summary:")
print(re.describe())
# Out:
# Statistical Summary:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
# Checking for missing values

print("\nMissing values in each column:")
print(re.isnull().sum())
# Out:
# Missing values in each column:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
#Handling missing values

re['Cuisines'] = re['Cuisines'].fillna(re['Cuisines'].mode()[0])

# %%
#Checking again for missing values

print("\nMissing values in each column:")
print(re.isnull().sum())
# Out:
# Missing values in each column:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# Unique Values

print("\nNumber of unique values in each column:")
print(re.nunique())
# Out:
# Number of unique values in each column:
# Restaurant ID           9551
# Restaurant Name         7446
# Country Code              15
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# dtype: int64

# %%
# Analyzing the distribution of the target variable

plt.figure(figsize=(8, 6))
sns.countplot(re['Aggregate rating'])
plt.title('Distribution of Aggregate Ratings')
plt.xlabel('Ratings')
plt.ylabel('Count')
plt.show()

# %%
# Checking for class imbalances

class_counts = re['Aggregate rating'].value_counts()
print("\nClass Imbalances:")
print(class_counts)
# Out:
# Class Imbalances:
# Aggregate rating
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: count, dtype: int64

# %% [markdown]
# __Level - 1 Task - 2
# Task: Descriptive Analysis__

# %%
#Getting summary statistics for numerical columns

numerical_stats = re.describe()
print(numerical_stats)
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
# For Country Code

country_counts = re['Country Code'].value_counts()
print("Country Code Distribution:")
print(country_counts)
# Out:
# Country Code Distribution:
# Country Code
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: count, dtype: int64

# %%
# For City

city_counts = re['City'].value_counts()
print("\nCity Distribution:")
print(city_counts)
# Out:
# City Distribution:
# City
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: count, Length: 141, dtype: int64

# %%
#For Cuisines

cuisine_counts = re['Cuisines'].str.split(', ', expand=True).stack().value_counts()
print("\nCuisine Distribution:")
print(cuisine_counts)
# Out:
# Cuisine Distribution:
# North Indian      3969
# Chinese           2735
# Fast Food         1986
# Mughlai            995
# Italian            764
#                   ...
# Fish and Chips       1
# Malwani              1
# Cuisine Varies       1
# Mineira              1
# B�_rek               1
# Name: count, Length: 145, dtype: int64

# %%
# Top cuisines

top_cuisines = cuisine_counts.head(10)
print("\nTop Cuisines:")
print(top_cuisines)
# Out:
# Top Cuisines:
# North Indian    3969
# Chinese         2735
# Fast Food       1986
# Mughlai          995
# Italian          764
# Bakery           745
# Continental      736
# Cafe             703
# Desserts         653
# South Indian     636
# Name: count, dtype: int64

# %%
# Top cities with highest number of restaurants

top_cities = city_counts.head(10)
print("\nTop Cities with Highest Number of Restaurants:")
print(top_cities)
# Out:
# Top Cities with Highest Number of Restaurants:
# City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Bhubaneshwar      21
# Amritsar          21
# Ahmedabad         21
# Lucknow           21
# Guwahati          21
# Name: count, dtype: int64

# %% [markdown]
# __Level - 1 Task - 3
# Task: Geospatial Analysis

# %%
# Plotting restaurant locations

plt.figure(figsize=(10, 6))
plt.scatter(re['Longitude'], re['Latitude'], alpha=0.5)
plt.title('Restaurant Locations')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()

# %%
# Analyzing distribution of restaurants by city

city_counts = re['City'].value_counts()
plt.figure(figsize=(15, 9))
city_counts.plot(kind='bar')
plt.title('Number of Restaurants by City')
plt.xlabel('City')
plt.ylabel('Number of Restaurants')
plt.xticks(rotation=45)
plt.show()

# %%
# Analyzing distribution of restaurants by country

country_counts = re['Country Code'].value_counts()
plt.figure(figsize=(10, 6))
country_counts.plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of Restaurants by Country')
plt.ylabel('')
plt.show()

# %%
# Correlation between restaurant location and rating 

plt.figure(figsize=(10, 6))
plt.scatter(re['Longitude'], re['Latitude'], c=re['Aggregate rating'], cmap='viridis', alpha=0.5)
plt.colorbar(label='Aggregate Rating')
plt.title('Restaurant Locations with Ratings')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()
